# %%
import matplotlib.pyplot as plt

# Données
datasets = ['Iris', 'Diabète', 'Breast_cancer', 'Digits', 'Aléatoire']
m_values = [2, 4, 5, 6, 8]
depths = [6, 36, 104, 226, 964]
depths1= [10, 32, 44, 56, 80]
q= [14, 62, 126, 254, 1022]

m_values1 = [4, 6, 8, 10, 12]
q1=[28,76,124,252, 508]

# Création du graphique
plt.figure(figsize=(10, 6))
plt.plot(m_values1, q1, marker='o', linestyle='-', color='b')

# Ajout des labels et du titre
plt.xlabel('Nombre de qubits à encoder (m)')
plt.ylabel('Nombre de qubits totaux')
plt.title('Relation entre le nombre de qubits à encoder et le nombre de qubits totaux')

# Affichage de la grille
plt.grid(True)

# Affichage du graphique
plt.show()
